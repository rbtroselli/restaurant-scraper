# %%
import pandas as pd

# %%
df = pd.read_csv('restaurant.csv',sep='|')

# %%
df
# Out:
#              id                                 name  rank  \
# 0     d17805000                   Mabuhay Restaurant   5.0
# 1     d24167962                        Parea Bistrot   5.0
# 2     d15831930  BLUE M Milano - Bottega Marchigiana   5.0
# 3      d6158885                            Il Panino   5.0
# 4      d9558612                 Kebabbar Star Zagros   5.0
# ...         ...                                  ...   ...
# 1205   d2618436                        Bistro Milano   3.5
# 1206    d716418                              Mio Lab   4.5
# 1207  d10542528              Pizzeria Piccola Ischia   4.0
# 1208  d12542801                Panzerotto Mio Baggio   4.5
# 1209   d8482314            212 Hamburger & Delicious   4.0
#
#                                                 address          phone  \
# 0        Bastioni di Porta Volta 9, 20121 Milano Italia  +390230065018
# 1                      Via Vigna 6, 20123 Milano Italia  +390247751500
# ...
